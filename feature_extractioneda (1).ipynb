# %%
import os
import pandas as pd

def read_eda_files(root_folder):
    all_data = pd.DataFrame(columns=['ID', 'Task', 'EDA'])  # DataFrame to store the EDA data

    # Recursive traversal of all files in the root folder
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            # Check if the file is an EDA data file
            if file.endswith("_eda_data_filtered.csv"):
                # Extract the individual ID and task from the file name
                file_parts = file.split('_')
                id = file_parts[0]  # Assuming the individual ID is the first part of the file name
                task = file_parts[1]  # Assuming the task is the second part of the file name

                # Read the EDA data from the file and add it to the DataFrame
                try:
                    eda_data = pd.read_csv(os.path.join(root, file))
                    eda_values = eda_data.values.flatten()
                    
                    
                    df = pd.DataFrame({'ID': id, 'Task': task, 'EDA': eda_values})
                    all_data = pd.concat([all_data, df], ignore_index=True)
                except Exception as e:
                    print(f"Error reading file {file}: {e}")

    return all_data

# Root folder containing the EDA data files
root_folder = r"C:\Users\manar.gani\Project\PREPROCESSING"
print(root_folder)

# Read all EDA files and store them in a DataFrame
eda_df = read_eda_files(root_folder)

# Display the first few rows of the DataFrame
print(eda_df.head())
# Out:
# C:\Users\manar.gani\Project\PREPROCESSING
#      ID      Task                             EDA
# 0  2ea4  Baseline     0.0;39014;39010.66153676501
# 1  2ea4  Baseline     0.0;38980;39006.03390851931
# 2  2ea4  Baseline   0.002;38951;39001.35582154851
# 3  2ea4  Baseline  0.004;38935;38996.628609727966
# 4  2ea4  Baseline   0.006;38919;38991.85362939295

# %%
eda_df
# Out:
#             ID      Task                             EDA
# 0         2ea4  Baseline     0.0;39014;39010.66153676501
# 1         2ea4  Baseline     0.0;38980;39006.03390851931
# 2         2ea4  Baseline   0.002;38951;39001.35582154851
# 3         2ea4  Baseline  0.004;38935;38996.628609727966
# 4         2ea4  Baseline   0.006;38919;38991.85362939295
# ...        ...       ...                             ...
# 34967995  y9z6    Video2   59.994;4244;4305.111262790446
# 34967996  y9z6    Video2  59.995;4246;4305.1097931467475
# 34967997  y9z6    Video2   59.996;4238;4305.108587412919
# 34967998  y9z6    Video2   59.997;4226;4305.107610946266
# 34967999  y9z6    Video2   59.998;4287;4305.106831576423
#
# [34968000 rows x 3 columns]

# %%
eda_df['EDA'] = eda_df['EDA'].str.split(';').str[-1]

# %%
eda_df
# Out:
#             ID      Task                 EDA
# 0         2ea4  Baseline   39010.66153676501
# 1         2ea4  Baseline   39006.03390851931
# 2         2ea4  Baseline   39001.35582154851
# 3         2ea4  Baseline  38996.628609727966
# 4         2ea4  Baseline   38991.85362939295
# ...        ...       ...                 ...
# 34967995  y9z6    Video2   4305.111262790446
# 34967996  y9z6    Video2  4305.1097931467475
# 34967997  y9z6    Video2   4305.108587412919
# 34967998  y9z6    Video2   4305.107610946266
# 34967999  y9z6    Video2   4305.106831576423
#
# [34968000 rows x 3 columns]

# %%
eda_df.to_csv('filtered_eda_data.csv', index=False)

# %%
def eda_stat(array, sampling_freq=500):
    x = np.array(array)
    eda = nk.eda_phasic(x, sampling_freq)
    scr = np.array(eda['EDA_Phasic'])
    scl = np.array(eda['EDA_Tonic'])
    x_axis = np.linspace(0, scl.shape[0]/sampling_freq, scl.shape[0])
    slope = np.polyfit(x_axis,scl,1)[0]
    
    df = pd.DataFrame(data = [x.max(), x.min(), x.mean(), x.std(),
                              stats.kurtosis(x), stats.skew(x), np.quantile(x,0.5),
                              x.max()/x.min(), slope, scr.max(), scr.min(), scr.mean(), scr.std(),
                              scl.max(), scl.min(), scl.mean(), scl.std()]).T

    df.columns = ['max_eda', 'min_eda', 'mean_eda', 'sd_eda', 'ku_eda', 'sk_eda', 'median_eda',
                  'dynrange','scl_slope', 'max_scr', 'min_scr', 'mean_scr', 'sd_scr', 'max_scl', 
                  'min_scl', 'mean_scl', 'sd_scl']
    
    return df

# %%
def eda_time(array, sampling_freq=500):
    x = np.array(array)
    eda = nk.eda_phasic(x, sampling_freq)
    scr = np.array(eda['EDA_Phasic'])
    
    _, info = nk.eda_peaks(scr, sampling_freq)
    peaks = info['SCR_Peaks']
    amplitude = info['SCR_Amplitude']
    recovery = info['SCR_RecoveryTime']
    
    nSCR = len(info['SCR_Peaks']) / (x.shape[0]/sampling_freq/60)
    aucSCR = np.trapz(scr)
    meanAmpSCR = np.nanmean(amplitude)
    maxAmpSCR = np.nanmax(amplitude)
    meanRespSCR = np.nanmean(recovery)
    sumAmpSCR = np.nansum(amplitude) / (x.shape[0]/sampling_freq/60)
    sumRespSCR = np.nansum(recovery) / (x.shape[0]/sampling_freq/60)

    df = pd.DataFrame(data = [nSCR, aucSCR, meanAmpSCR, maxAmpSCR, meanRespSCR,
                             sumAmpSCR, sumRespSCR]).T
    
    df.columns = ['nSCR', 'aucSCR', 'meanAmpSCR', 'maxAmpSCR', 'meanRespSCR',
                  'sumAmpSCR', 'sumRespSCR']
    return df

# %%
def feature_extraction(root_folder):

    # Recursive traversal of all files in the root folder
    features = pd.DataFrame()
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            # Check if the file is an EDA data file
            if file.endswith('_eda_data_filtered.csv'):  #find all the RR file: "_rr_filtered.csv"
                # Extract the individual ID and task from the file name
                file_parts = file.split('_')
                idy = file_parts[0]  # Assuming the individual ID is the first part of the file name
                task = file_parts[1]  # Assuming the task is the second part of the file name

                # Read the EDA data from the file and add it to the DataFrame
                try:
                    eda_data = pd.read_csv(os.path.join(root, file),  sep=';')
                    # Calcule la moyenne des valeurs de la troisième colonne du fichier rr_data
                    signal_neurokit, info_neurokit=nk.eda_process(eda_df.values, sampling_rate=500)
                    signal_filtered=signal_neurokit['EDA_Clean']
                    df_stat = eda_stat(signal_filtered, sampling_freq)
                    df_time = eda_time(signal_filtered, sampling_freq)
                    identity=pd.DataFrame({'ID':[idy], 'Task':[task]})
                    features= pd.concat([identity, df_time, df_stat], axis=1)
                    

                    
                    
                except Exception as e:
                    print(f"Error reading file {file}: {e}")

    return features

# %%
root_folder=r"C:\Users\manar.gani\Project\PREPROCESSING"
features=feature_extraction(root_folder)
# Out:
# Error reading file 2ea4_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2ea4_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2hpu_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 2z7d_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 37ir_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 45lx_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4e8r_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 4woj_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 5f7t_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6g6y_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 6k5f_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 71i5_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7h5u_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 7m3c_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8g4y_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 8i4i_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9j3o_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9t6n_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file 9txq_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file a1k9_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file b2l8_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file b2l8_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file b2l8_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file b2l8_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# ...
# Error reading file v8mh_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file v8mh_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file v8mh_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file v8mh_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file v8mh_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file v8mh_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file w2t5_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wfsl_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file wssm_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file x1q3_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y8c3_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Baseline_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Breathing_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Counting1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Counting2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Counting3_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Math_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Reading_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Relax_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Speaking_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Stroop_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Video1_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
# Error reading file y9z6_Video2_eda_data_filtered.csv: NeuroKit error: we expect the user to provide a vector, i.e., a one-dimensional array (such as a list of values). Current input of shape: (34968000, 3)
